# %%
import pandas as pd
import numpy as ns

# %%
#read a csv file into dataframe
df = pd.read_csv("mainflow.csv")
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#display the first 5 rows of data
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
#display the last 5 rows of data
df.tail()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 319        347.286         310.970  1.523       513.956  ...        61.141
# 320        399.135         319.576  1.451       570.058  ...        67.667
# 321        373.633         314.591  1.457       549.306  ...        66.446
# 322        364.081         308.559  1.523       504.852  ...        61.054
# 323        356.289         310.482  1.474       497.375  ...        58.247
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
#displaying the data types in the columns in the data
print("/ndata types of the column in the departement:")
print(df.dtypes)
# Out:
# /ndata types of the column in the departement:
# Observation         object
# Y-Kappa            float64
# ChipRate           float64
# BF-CMratio         float64
# BlowFlow           float64
# ChipLevel4         float64
# T-upperExt-2       float64
# T-lowerExt-2       float64
# UCZAA              float64
# WhiteFlow-4        float64
# AAWhiteSt-4        float64
# AA-Wood-4          float64
# ChipMoisture-4     float64
# SteamFlow-4        float64
# Lower-HeatT-3      float64
# Upper-HeatT-3      float64
# ChipMass-4         float64
# WeakLiquorF        float64
# BlackFlow-2        float64
# WeakWashF          float64
# SteamHeatF-3       float64
# T-Top-Chips-4      float64
# SulphidityL-4      float64
# dtype: object

# %%
# droping the duplicate values
df = df.drop_duplicates()
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
df.notnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           True     True      True        True      True         True
# 1           True     True      True        True      True         True
# 2           True     True      True        True      True         True
# 3           True     True      True        True      True         True
# 4           True     True      True        True      True         True
# ..           ...      ...       ...         ...       ...          ...
# 298         True     True      True        True      True         True
# 299         True     True     False        True      True         True
# 300         True     True     False        True      True         True
# 301         True     True     False        True      True         True
# 307         True     True      True        True      True         True
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 352

# %%
#fillinf missing values with 0
df1 = df.fillna(0)
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#filling missing values with forward fill
df1.ffill(inplace=True)
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#filling missing values with backward fill
df1.bfill(inplace=True)
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
import matplotlib as plt
from scipy import stats

# %%
df.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Y-Kappa              4.55000
# ChipRate             2.13400
# BF-CMratio          10.40000
# BlowFlow            94.34275
# ChipLevel4         105.91575
# T-upperExt-2        12.00925
# T-lowerExt-2         7.59525
# UCZAA                0.13200
# WhiteFlow-4        100.42925
# AAWhiteSt-4          0.10700
# AA-Wood-4            1.48025
# ChipMoisture-4       2.18675
# SteamFlow-4          8.80300
# Lower-HeatT-3        8.58325
# Upper-HeatT-3        7.81000
# ChipMass-4          19.19700
# WeakLiquorF        178.80725
# BlackFlow-2        280.29425
# WeakWashF          264.32775
# SteamHeatF-3         6.90625
# T-Top-Chips-4        2.03400
# SulphidityL-4        0.73075
# dtype: float64

# %%
df=df[~((df<(Q1-1.5*IQR)|(df>(Q3+1.5*IQR))).any(axis=1))]        
df
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
# 299    24.98       NaN      85.034  1278.345      368.564        357.723
# 300    21.00       NaN      88.013  1307.722      278.842        357.438
# 301    21.40       NaN      85.490  1255.986      273.484        361.365
# 307    20.89    14.308      94.172  1327.832      251.120        351.263
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
#group data by a column and calculating the mean
print('/nGroup the data by a column and calculate the maean')
print(df.groupby("ChipRate").mean())
# Out:
# /nGroup the data by a column and calculate the maean
#           Y-Kappa  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# ChipRate
# 9.983       20.20     102.237  1027.485      369.632        342.576
# 10.625      22.50      89.193  1010.855      322.470        342.637
# 10.833      14.53      93.121  1202.818      339.119        342.535
# 10.933      22.10      97.752  1038.618      333.743        343.695
# 10.942      12.81     114.567  1241.142      215.485        346.411
# ...           ...         ...       ...          ...            ...
# 16.783      22.53      76.396  1281.536      269.496        351.640
# 16.810      27.60      79.022  1328.360      341.327        351.050
# 16.817      21.50      78.969  1237.844      285.892        353.644
# 16.867      23.50      76.937  1284.849      334.170        364.132
# 16.958      25.40      74.405  1230.776      295.522        350.216
#
#           T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   AA-Wood-4    ...  \
# ...

# %%
#sort the data by column
print('/Sort the data by a column')
print(df.sort_values("ChipRate"))
# Out:
# /Sort the data by a column
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 284    20.20     9.983     102.237  1027.485      369.632        342.576
# 289    22.50    10.625      89.193  1010.855      322.470        342.637
# 37     14.53    10.833      93.121  1202.818      339.119        342.535
# 288    22.10    10.933      97.752  1038.618      333.743        343.695
# 36     12.81    10.942     114.567  1241.142      215.485        346.411
# ..       ...       ...         ...       ...          ...            ...
# 99     23.50    16.867      76.937  1284.849      334.170        364.132
# 64     25.40    16.958      74.405  1230.776      295.522        350.216
# 299    24.98       NaN      85.034  1278.345      368.564        357.723
# 300    21.00       NaN      88.013  1307.722      278.842        357.438
# 301    21.40       NaN      85.490  1255.986      273.484        361.365
#
# ...

# %%
#filter rows where column_name is equal to value
df[df['ChipRate'] == 16.520]
# Out:
#    Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0     23.1     16.52     121.717  1177.607      169.805        358.282
#
#    T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# 0         329.545  1.443       599.253           NaN  ...        67.122
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 0        329.432         303.099      175.964      1127.197      1319.039
#
#    WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 0     257.325         54.612         252.077             NaN
#
# [1 rows x 22 columns]
